# %% [markdown]
# # Lorenz 96 path space annealing

# %% [markdown]
# Carry out path space annealing for a Lorenz 96 model, in an arbitrary number of dimensions $D$.

# %%
import numpy as np
import pyanneal

# %% [markdown]
# Let's set the path to the twin experiment data

# %%
datapath = 'l96_twindata_D20_L14_dt0p02.npy'
data = np.load(datapath)

# observation times, number of time points, measured components
times = data[:,0]
#dt = times[1:] - times[:-1]
dt = times[1] - times[0]
N = len(times)
t0 = times[0]
tf = times[-1]

# %% [markdown]
# Now define the ODE vector field.

# %%
def l96(x, t, k):
    return np.roll(x,1,1) * (np.roll(x,-1,1) - np.roll(x,2,1)) - x + k

# %% [markdown]
# Define model and twin experiment parameters

# %%
D = 20
P = (8.17*np.ones(D),)
Pidx = ()

Lidx = (0, 1, 3, 4, 6, 7, 9, 10, 12, 13, 15, 16, 18, 19)
L = len(Lidx)

RM = np.eye(L)/(0.2**2)
RF0_val = .0001 * dt**2
RF0 = RF0_val * np.eye(D)

# %% [markdown]
# Initial path guess

# %%
Xinit = (20.0*np.random.rand(N*D) - 10.0)

# %% [markdown]
# Annealing parameters

# %%
alpha = 1.5
beta_array = np.linspace(0.0, 70.0, 71)

# %% [markdown]
# Initialize a twin experiment

# %%
twin1 = pyanneal.TwinExperiment(l96, Lidx, RM, RF0, data_file=datapath, P=P, Pidx=Pidx)

# %% [markdown]
# Carry out a single annealing run

# %%
twin1.anneal(Xinit, alpha, beta_array, init_to_data=True, method='lbfgs_scipy', disc='impeuler')
# Out:
# ------------------------------
# Step 1 of 71
# alpha = 1.500000, beta = 0.000000
#
# Taping action evaluation...
# Time = 0.548734903336 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.0638360977173 s
# Exit flag = 0
# Iterations = 0
# Obj. function value = 0.000980094708062
#
# ------------------------------
# Step 2 of 71
# alpha = 1.500000, beta = 1.000000
#
# Taping action evaluation...
# Time = 0.562570810318 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.129086017609 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 1.42154486649e-05
#
# ------------------------------
# Step 3 of 71
# alpha = 1.500000, beta = 2.000000
#
# Taping action evaluation...
# Time = 0.568461894989 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.11976313591 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 2.13231301245e-05
#
# ------------------------------
# Step 4 of 71
# alpha = 1.500000, beta = 3.000000
#
# Taping action evaluation...
# Time = 0.570446968079 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.133616924286 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 3.19845987243e-05
#
# ------------------------------
# Step 5 of 71
# alpha = 1.500000, beta = 4.000000
#
# Taping action evaluation...
# Time = 0.632524013519 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.126179933548 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 4.79766810514e-05
#
# ------------------------------
# Step 6 of 71
# alpha = 1.500000, beta = 5.000000
#
# Taping action evaluation...
# Time = 0.587677001953 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.116250991821 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 7.19645332666e-05
#
# ------------------------------
# Step 7 of 71
# alpha = 1.500000, beta = 6.000000
#
# Taping action evaluation...
# Time = 0.600476980209 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.123420953751 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.000107945701263
#
# ------------------------------
# Step 8 of 71
# alpha = 1.500000, beta = 7.000000
#
# Taping action evaluation...
# Time = 0.595529079437 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.119171142578 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00016191608017
#
# ------------------------------
# Step 9 of 71
# alpha = 1.500000, beta = 8.000000
#
# Taping action evaluation...
# Time = 0.597304105759 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.117638111115 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00024286855958
#
# ------------------------------
# Step 10 of 71
# alpha = 1.500000, beta = 9.000000
#
# Taping action evaluation...
# Time = 0.618811130524 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.119248867035 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.000364290330225
#
# ------------------------------
# Step 11 of 71
# alpha = 1.500000, beta = 10.000000
#
# Taping action evaluation...
# Time = 0.652096033096 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.117885828018 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00054640735778
#
# ------------------------------
# Step 12 of 71
# alpha = 1.500000, beta = 11.000000
#
# Taping action evaluation...
# Time = 0.636041879654 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.116910934448 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.000819547754229
#
# ------------------------------
# Step 13 of 71
# alpha = 1.500000, beta = 12.000000
#
# Taping action evaluation...
# Time = 0.646234035492 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.117130041122 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00122917933719
#
# ------------------------------
# Step 14 of 71
# alpha = 1.500000, beta = 13.000000
#
# Taping action evaluation...
# Time = 0.676717996597 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.128000020981 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00184344915217
#
# ------------------------------
# Step 15 of 71
# alpha = 1.500000, beta = 14.000000
#
# Taping action evaluation...
# Time = 0.665507078171 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.118947982788 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00276445509796
#
# ------------------------------
# Step 16 of 71
# alpha = 1.500000, beta = 15.000000
#
# Taping action evaluation...
# Time = 0.664252996445 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.118721008301 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00414506923964
#
# ------------------------------
# Step 17 of 71
# alpha = 1.500000, beta = 16.000000
#
# Taping action evaluation...
# Time = 0.664297103882 s
#
# Beginning optimization...
# Optimization complete!
# Time = 0.117801904678 s
# Exit flag = 0
# Iterations = 2
# Obj. function value = 0.00621398554151
#
# ------------------------------
# Step 18 of 71
# alpha = 1.500000, beta = 17.000000
#
# Taping action evaluation...
# Time = 0.67621922493 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.68700003624 s
# Exit flag = 0
# Iterations = 80
# Obj. function value = 0.00384063135238
#
# ------------------------------
# Step 19 of 71
# alpha = 1.500000, beta = 18.000000
#
# Taping action evaluation...
# Time = 0.685347080231 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.14144015312 s
# Exit flag = 0
# Iterations = 100
# Obj. function value = 0.00507831786023
#
# ------------------------------
# Step 20 of 71
# alpha = 1.500000, beta = 19.000000
#
# Taping action evaluation...
# Time = 0.68952703476 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.70145201683 s
# Exit flag = 0
# Iterations = 121
# Obj. function value = 0.00695339223414
#
# ------------------------------
# Step 21 of 71
# alpha = 1.500000, beta = 20.000000
#
# Taping action evaluation...
# Time = 0.722949981689 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.78247594833 s
# Exit flag = 0
# Iterations = 130
# Obj. function value = 0.0098465645729
#
# ------------------------------
# Step 22 of 71
# alpha = 1.500000, beta = 21.000000
#
# Taping action evaluation...
# Time = 0.727421045303 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.0197467804 s
# Exit flag = 0
# Iterations = 141
# Obj. function value = 0.0142002726772
#
# ------------------------------
# Step 23 of 71
# alpha = 1.500000, beta = 22.000000
#
# Taping action evaluation...
# Time = 0.743771076202 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.17421102524 s
# Exit flag = 0
# Iterations = 155
# Obj. function value = 0.0203820159233
#
# ------------------------------
# Step 24 of 71
# alpha = 1.500000, beta = 23.000000
#
# Taping action evaluation...
# Time = 0.730218887329 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.16331386566 s
# Exit flag = 0
# Iterations = 152
# Obj. function value = 0.0294772568707
#
# ------------------------------
# Step 25 of 71
# alpha = 1.500000, beta = 24.000000
#
# Taping action evaluation...
# Time = 0.742741823196 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.81358599663 s
# Exit flag = 0
# Iterations = 138
# Obj. function value = 0.042327986328
#
# ------------------------------
# Step 26 of 71
# alpha = 1.500000, beta = 25.000000
#
# Taping action evaluation...
# Time = 0.771681070328 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.04896402359 s
# Exit flag = 0
# Iterations = 151
# Obj. function value = 0.0596317493907
#
# ------------------------------
# Step 27 of 71
# alpha = 1.500000, beta = 26.000000
#
# Taping action evaluation...
# Time = 0.755984067917 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.9856171608 s
# Exit flag = 0
# Iterations = 146
# Obj. function value = 0.0824341088102
#
# ------------------------------
# Step 28 of 71
# alpha = 1.500000, beta = 27.000000
#
# Taping action evaluation...
# Time = 0.771300077438 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.91986894608 s
# Exit flag = 0
# Iterations = 136
# Obj. function value = 0.110941822902
#
# ------------------------------
# Step 29 of 71
# alpha = 1.500000, beta = 28.000000
#
# Taping action evaluation...
# Time = 0.761600017548 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.60213112831 s
# Exit flag = 0
# Iterations = 127
# Obj. function value = 0.144643452723
#
# ------------------------------
# Step 30 of 71
# alpha = 1.500000, beta = 29.000000
#
# Taping action evaluation...
# Time = 0.799216985703 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.66180205345 s
# Exit flag = 0
# Iterations = 129
# Obj. function value = 0.182131768743
#
# ------------------------------
# Step 31 of 71
# alpha = 1.500000, beta = 30.000000
#
# Taping action evaluation...
# Time = 0.855465888977 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.70221304893 s
# Exit flag = 0
# Iterations = 125
# Obj. function value = 0.221448718568
#
# ------------------------------
# Step 32 of 71
# alpha = 1.500000, beta = 31.000000
#
# Taping action evaluation...
# Time = 0.854772806168 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.47071909904 s
# Exit flag = 0
# Iterations = 121
# Obj. function value = 0.260433731496
#
# ------------------------------
# Step 33 of 71
# alpha = 1.500000, beta = 32.000000
#
# Taping action evaluation...
# Time = 0.8494348526 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.59528803825 s
# Exit flag = 0
# Iterations = 127
# Obj. function value = 0.297235432501
#
# ------------------------------
# Step 34 of 71
# alpha = 1.500000, beta = 33.000000
#
# Taping action evaluation...
# Time = 0.865612983704 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.89034295082 s
# Exit flag = 0
# Iterations = 134
# Obj. function value = 0.33066260233
#
# ------------------------------
# Step 35 of 71
# alpha = 1.500000, beta = 34.000000
#
# Taping action evaluation...
# Time = 0.890408992767 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.82793903351 s
# Exit flag = 0
# Iterations = 136
# Obj. function value = 0.360120731786
#
# ------------------------------
# Step 36 of 71
# alpha = 1.500000, beta = 35.000000
#
# Taping action evaluation...
# Time = 0.925158023834 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.07987093925 s
# Exit flag = 0
# Iterations = 151
# Obj. function value = 0.385493676336
#
# ------------------------------
# Step 37 of 71
# alpha = 1.500000, beta = 36.000000
#
# Taping action evaluation...
# Time = 0.872861862183 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.20901894569 s
# Exit flag = 0
# Iterations = 157
# Obj. function value = 0.40701587194
#
# ------------------------------
# Step 38 of 71
# alpha = 1.500000, beta = 37.000000
#
# Taping action evaluation...
# Time = 0.931099891663 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.42515492439 s
# Exit flag = 0
# Iterations = 164
# Obj. function value = 0.425053309881
#
# ------------------------------
# Step 39 of 71
# alpha = 1.500000, beta = 38.000000
#
# Taping action evaluation...
# Time = 0.946478843689 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.61760401726 s
# Exit flag = 0
# Iterations = 176
# Obj. function value = 0.440046000707
#
# ------------------------------
# Step 40 of 71
# alpha = 1.500000, beta = 39.000000
#
# Taping action evaluation...
# Time = 1.01117992401 s
#
# Beginning optimization...
# Optimization complete!
# Time = 5.13048696518 s
# Exit flag = 0
# Iterations = 194
# Obj. function value = 0.452431614834
#
# ------------------------------
# Step 41 of 71
# alpha = 1.500000, beta = 40.000000
#
# Taping action evaluation...
# Time = 1.1731069088 s
#
# Beginning optimization...
# Optimization complete!
# Time = 5.84149193764 s
# Exit flag = 0
# Iterations = 210
# Obj. function value = 0.462616769307
#
# ------------------------------
# Step 42 of 71
# alpha = 1.500000, beta = 41.000000
#
# Taping action evaluation...
# Time = 1.34745502472 s
#
# Beginning optimization...
# Optimization complete!
# Time = 6.17678999901 s
# Exit flag = 0
# Iterations = 238
# Obj. function value = 0.470954720207
#
# ------------------------------
# Step 43 of 71
# alpha = 1.500000, beta = 42.000000
#
# Taping action evaluation...
# Time = 1.17483901978 s
#
# Beginning optimization...
# Optimization complete!
# Time = 6.27052402496 s
# Exit flag = 0
# Iterations = 259
# Obj. function value = 0.477752745066
#
# ------------------------------
# Step 44 of 71
# alpha = 1.500000, beta = 43.000000
#
# Taping action evaluation...
# Time = 1.13756203651 s
#
# Beginning optimization...
# Optimization complete!
# Time = 6.70164299011 s
# Exit flag = 0
# Iterations = 310
# Obj. function value = 0.483271390893
#
# ------------------------------
# Step 45 of 71
# alpha = 1.500000, beta = 44.000000
#
# Taping action evaluation...
# Time = 1.04626107216 s
#
# Beginning optimization...
# Optimization complete!
# Time = 6.95014190674 s
# Exit flag = 0
# Iterations = 347
# Obj. function value = 0.487741495024
#
# ------------------------------
# Step 46 of 71
# alpha = 1.500000, beta = 45.000000
#
# Taping action evaluation...
# Time = 1.32145881653 s
#
# Beginning optimization...
# Optimization complete!
# Time = 9.32589411736 s
# Exit flag = 0
# Iterations = 415
# Obj. function value = 0.491362814681
#
# ------------------------------
# Step 47 of 71
# alpha = 1.500000, beta = 46.000000
#
# Taping action evaluation...
# Time = 1.07521009445 s
#
# Beginning optimization...
# Optimization complete!
# Time = 9.88664698601 s
# Exit flag = 0
# Iterations = 481
# Obj. function value = 0.494310173468
#
# ------------------------------
# Step 48 of 71
# alpha = 1.500000, beta = 47.000000
#
# Taping action evaluation...
# Time = 1.11266303062 s
#
# Beginning optimization...
# Optimization complete!
# Time = 11.8289921284 s
# Exit flag = 0
# Iterations = 584
# Obj. function value = 0.496730244635
#
# ------------------------------
# Step 49 of 71
# alpha = 1.500000, beta = 48.000000
#
# Taping action evaluation...
# Time = 1.1361758709 s
#
# Beginning optimization...
# Optimization complete!
# Time = 13.7812130451 s
# Exit flag = 0
# Iterations = 690
# Obj. function value = 0.498742193752
#
# ------------------------------
# Step 50 of 71
# alpha = 1.500000, beta = 49.000000
#
# Taping action evaluation...
# Time = 1.23069906235 s
#
# Beginning optimization...
# Optimization complete!
# Time = 18.8696050644 s
# Exit flag = 0
# Iterations = 878
# Obj. function value = 0.500441973944
#
# ------------------------------
# Step 51 of 71
# alpha = 1.500000, beta = 50.000000
#
# Taping action evaluation...
# Time = 1.2569000721 s
#
# Beginning optimization...
# Optimization complete!
# Time = 30.7617080212 s
# Exit flag = 0
# Iterations = 1297
# Obj. function value = 0.501905447068
#
# ------------------------------
# Step 52 of 71
# alpha = 1.500000, beta = 51.000000
#
# Taping action evaluation...
# Time = 0.949352025986 s
#
# Beginning optimization...
# Optimization complete!
# Time = 31.6680629253 s
# Exit flag = 0
# Iterations = 1480
# Obj. function value = 31.9672026108
#
# ------------------------------
# Step 53 of 71
# alpha = 1.500000, beta = 52.000000
#
# Taping action evaluation...
# Time = 0.868839979172 s
#
# Beginning optimization...
# Optimization complete!
# Time = 54.7703938484 s
# Exit flag = 0
# Iterations = 2530
# Obj. function value = 45.7872790537
#
# ------------------------------
# Step 54 of 71
# alpha = 1.500000, beta = 53.000000
#
# Taping action evaluation...
# Time = 0.90362405777 s
#
# Beginning optimization...
# Optimization complete!
# Time = 148.712205887 s
# Exit flag = 0
# Iterations = 6758
# Obj. function value = 69.4827937518
#
# ------------------------------
# Step 55 of 71
# alpha = 1.500000, beta = 54.000000
#
# Taping action evaluation...
# Time = 0.90535902977 s
#
# Beginning optimization...
# Optimization complete!
# Time = 208.734745026 s
# Exit flag = 0
# Iterations = 10488
# Obj. function value = 46.2239520923
#
# ------------------------------
# Step 56 of 71
# alpha = 1.500000, beta = 55.000000
#
# Taping action evaluation...
# Time = 0.888941049576 s
#
# Beginning optimization...
# Optimization complete!
# Time = 306.264406919 s
# Exit flag = 1
# Iterations = 14620
# Obj. function value = 98.0200566364
#
# ------------------------------
# Step 57 of 71
# alpha = 1.500000, beta = 56.000000
#
# Taping action evaluation...
# Time = 0.902772188187 s
#
# Beginning optimization...
# Optimization complete!
# Time = 323.98983717 s
# Exit flag = 1
# Iterations = 14604
# Obj. function value = 165.707726954
#
# ------------------------------
# Step 58 of 71
# alpha = 1.500000, beta = 57.000000
#
# Taping action evaluation...
# Time = 1.26413702965 s
#
# Beginning optimization...
# Optimization complete!
# Time = 297.977837801 s
# Exit flag = 1
# Iterations = 14632
# Obj. function value = 246.412939594
#
# ------------------------------
# Step 59 of 71
# alpha = 1.500000, beta = 58.000000
#
# Taping action evaluation...
# Time = 0.930392980576 s
#
# Beginning optimization...
# Optimization complete!
# Time = 290.460151911 s
# Exit flag = 1
# Iterations = 14637
# Obj. function value = 256.572825151
#
# ------------------------------
# Step 60 of 71
# alpha = 1.500000, beta = 59.000000
#
# Taping action evaluation...
# Time = 0.944288015366 s
#
# Beginning optimization...
# Optimization complete!
# Time = 297.35219717 s
# Exit flag = 1
# Iterations = 14614
# Obj. function value = 320.055152407
#
# ------------------------------
# Step 61 of 71
# alpha = 1.500000, beta = 60.000000
#
# Taping action evaluation...
# Time = 0.966368913651 s
#
# Beginning optimization...
# Optimization complete!
# Time = 201.146039009 s
# Exit flag = 0
# Iterations = 10321
# Obj. function value = 362.882058612
#
# ------------------------------
# Step 62 of 71
# alpha = 1.500000, beta = 61.000000
#
# Taping action evaluation...
# Time = 0.970904827118 s
#
# Beginning optimization...
# Optimization complete!
# Time = 283.505153894 s
# Exit flag = 1
# Iterations = 14656
# Obj. function value = 334.236766263
#
# ------------------------------
# Step 63 of 71
# alpha = 1.500000, beta = 62.000000
#
# Taping action evaluation...
# Time = 0.981323003769 s
#
# Beginning optimization...
# Optimization complete!
# Time = 280.708504915 s
# Exit flag = 1
# Iterations = 14637
# Obj. function value = 364.757998219
#
# ------------------------------
# Step 64 of 71
# alpha = 1.500000, beta = 63.000000
#
# Taping action evaluation...
# Time = 0.964211940765 s
#
# Beginning optimization...
# Optimization complete!
# Time = 280.107002974 s
# Exit flag = 1
# Iterations = 14623
# Obj. function value = 365.476172129
#
# ------------------------------
# Step 65 of 71
# alpha = 1.500000, beta = 64.000000
#
# Taping action evaluation...
# Time = 0.980530977249 s
#
# Beginning optimization...
# Optimization complete!
# Time = 281.043315172 s
# Exit flag = 1
# Iterations = 14618
# Obj. function value = 368.135131308
#
# ------------------------------
# Step 66 of 71
# alpha = 1.500000, beta = 65.000000
#
# Taping action evaluation...
# Time = 0.993656158447 s
#
# Beginning optimization...
# Optimization complete!
# Time = 280.855010986 s
# Exit flag = 1
# Iterations = 14626
# Obj. function value = 375.573295321
#
# ------------------------------
# Step 67 of 71
# alpha = 1.500000, beta = 66.000000
#
# Taping action evaluation...
# Time = 0.994448900223 s
#
# Beginning optimization...
# Optimization complete!
# Time = 281.06407094 s
# Exit flag = 1
# Iterations = 14615
# Obj. function value = 385.084409708
#
# ------------------------------
# Step 68 of 71
# alpha = 1.500000, beta = 67.000000
#
# Taping action evaluation...
# Time = 1.01949191093 s
#
# Beginning optimization...
# Optimization complete!
# Time = 281.193066835 s
# Exit flag = 1
# Iterations = 14641
# Obj. function value = 393.02250294
#
# ------------------------------
# Step 69 of 71
# alpha = 1.500000, beta = 68.000000
#
# Taping action evaluation...
# Time = 0.997914075851 s
#
# Beginning optimization...
# Optimization complete!
# Time = 284.069467068 s
# Exit flag = 1
# Iterations = 14633
# Obj. function value = 400.874544902
#
# ------------------------------
# Step 70 of 71
# alpha = 1.500000, beta = 69.000000
#
# Taping action evaluation...
# Time = 1.01561021805 s
#
# Beginning optimization...
# Optimization complete!
# Time = 289.87945199 s
# Exit flag = 1
# Iterations = 14642
# Obj. function value = 404.125125718
#
# ------------------------------
# Step 71 of 71
# alpha = 1.500000, beta = 70.000000
#
# Taping action evaluation...
# Time = 0.98842382431 s
#
# Beginning optimization...
# Optimization complete!
# Time = 287.833338976 s
# Exit flag = 1
# Iterations = 14597
# Obj. function value = 406.992275836
